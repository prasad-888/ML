# %% [markdown]
# ### Visualizing KNN
# Imagine a field where each flower represents a data point. Different species are marked with different colors. If a new flower is introduced, KNN looks at the nearest neighbors (flowers) to decide which species it belongs to. By experimenting with different values of K, you can see the boundaries shift and predictions stabilize

# %% [markdown]
# ![knn_visual.png](attachment:33bd2145-d7d6-4dde-ba23-6d30556994f1.png)
