# %% [markdown]
# Types of Boosting Algorithms
# 1. AdaBoost(Adaptive Boosting)
# 2. Gradient Boosting
# 3. XGBoost(Extreme Gradient Boosting)

# %% [markdown]
# ### AdaBoost
# implementing adaboost

# %%
import pandas as pd
import numpy as np


from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# %%
df = pd.read_csv(r"C:\Users\Prasad\Desktop\ml\data_ml\employee_train_dataset_main.csv")

# %%
df.head()
# Out:
#    S.No         Timestamp  Age  Gender         Country state self_employed  \
# 0     1  01-01-2021 09:14   37  Female   United States    IL           NaN
# 1     2  01-01-2021 09:26   44       M   United States    IN           NaN
# 2     3  01-01-2021 09:28   32    Male          Canada   NaN           NaN
# 3     4  01-01-2021 09:29   31    Male  United Kingdom   NaN           NaN
# 4     5  01-01-2021 09:30   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere  ...               leave  \
# 0             No       Yes          Often  ...       Somewhat easy
# 1             No        No         Rarely  ...          Don't know
# 2             No        No         Rarely  ...  Somewhat difficult
# 3            Yes       Yes          Often  ...  Somewhat difficult
# 4             No        No          Never  ...          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# ...

# %%
df.columns
# Out:
# Index(['S.No', 'Timestamp', 'Age', 'Gender', 'Country', 'state',
#        'self_employed', 'family_history', 'treatment', 'work_interfere',
#        'no_employees', 'remote_work', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# S.No   Timestamp         Age  Gender  Country        state  self_employed  family_history  treatment  work_interfere  no_employees    remote_work  tech_company  benefits    care_options  wellness_program  seek_help   anonymity   leave               mental_health_consequence  phys_health_consequence  coworkers     supervisor    mental_health_interview  phys_health_interview  mental_vs_physical  obs_consequence  comments
# ...

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# S.No
# 1        1
# 33351    1
# 33329    1
# 33330    1
# 33331    1
#         ..
# 16669    1
# 16670    1
# 16671    1
# 16672    1
# 50000    1
# Name: count, Length: 50000, dtype: int64
# Timestamp
# 26-01-2022 13:05    3
# 21-01-2023 09:31    3
# 28-09-2023 17:51    3
# 09-12-2023 16:14    3
# 06-12-2021 13:29    3
#                    ..
# 08-01-2022 17:08    1
# 08-01-2022 17:32    1
# 08-01-2022 17:40    1
# 08-01-2022 17:44    1
# 31-12-2023 18:59    1
# Name: count, Length: 48178, dtype: int64
# Age
#  29             3512
#  32             3055
#  33             3007
#  27             2964
#  26             2941
#  31             2691
#  28             2671
#  30             2668
#  34             2475
#  35             2326
#  25             2284
#  23             1968
#  24             1846
#  37             1719
#  36             1477
#  38             1453
#  39             1254
#  40             1184
#  43             1109
#  22              971
# ...

# %%
df_test = pd.read_csv(r"C:\Users\Prasad\Desktop\ml\data_ml\employee_test_dataset_main.csv")

# %%
## Data Preprocessing

# %%
df.drop(columns=['S.No','comments'], inplace=True)

# explanation of inplace
# so if we set it as true we modify the main/original dataframe directly
# if we set it as false we do not modify the original dataframe, it returns a new dataframe with the change

# %%
df_test.drop(columns=['S.No','comments'], inplace=True)

# %%
df.shape, df_test.shape
# Out:
# ((50000, 26), (20000, 25))

# %%
for col in df.columns:
    print(col,df[col].dtypes)
# Out:
# Timestamp object
# Age int64
# Gender object
# Country object
# state object
# self_employed object
# family_history object
# treatment object
# work_interfere object
# no_employees object
# remote_work object
# tech_company object
# benefits object
# care_options object
# wellness_program object
# seek_help object
# anonymity object
# leave object
# mental_health_consequence object
# phys_health_consequence object
# coworkers object
# supervisor object
# mental_health_interview object
# phys_health_interview object
# mental_vs_physical object
# obs_consequence object

# %%
df['Timestamp'][0]
# Out:
# '01-01-2021 09:14'

# %%
df_test['Timestamp'][0]
# Out:
# '01-01-2024 09:18'

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], format="%d-%m-%Y %H:%M")
df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'], format="%d-%m-%Y %H:%M")

# %%
df['Timestamp'][0]
# Out:
# Timestamp('2021-01-01 09:14:00')

# %% [markdown]
# # Data Transformation

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male                        24756
# male                         7809
# M                            4754
# Female                       4703
# female                       2257
# F                            1579
# m                            1402
# f                             607
# Make                          194
# Female                         97
# Cis Male                       97
# Woman                          97
# Man                            96
# Female (trans)                 72
# woman                          49
# fluid                          49
# Enby                           49
# All                            49
# Genderqueer                    49
# Nah                            49
# Femake                         49
# queer/she/they                 49
# Male (CIS)                     49
# Mal                            49
# something kinda male?          49
# Cis Female                     49
# Trans-female                   49
# ...
